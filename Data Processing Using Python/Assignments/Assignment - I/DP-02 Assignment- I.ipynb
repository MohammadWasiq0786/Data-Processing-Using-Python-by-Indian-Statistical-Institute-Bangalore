# %% [markdown]
# ### Name - Mohammad Wasiq
# ### E-mail - mohammadwasiq0786@gmail.com
# ### Assignment - I
# 1. Company manufacturing valves are facing the problem of high torque variation in their actuator subassembly. The company wants to identify the variables impacting the torque variation in actuator subassembly. Through brainstorming the project team have identified seven variables suspected to influence the torque variation.
#  1. The company has two manufacturing plants located at Bangalore and Pune. The data collected from Bangalore plant is given in Actuator_1 file and that from Pune plant is given in Actuator_II file. Join these files into a single dataset ?
#  2. Provide the descriptive summary of all the variables. For categorical variables provide summary using frequency table. Also provide the graphical summary of each variable using appropriate graphs like boxplot, histogram, pie chart, bar plot, etc?
#  3. Identify the relationship of explanatory variables with torque variation using appropriate data visualization technique? Give your interpretation

# %%
# Import the library
import pandas as pd

# Import the Ist dataset Actuator-I
data1 = pd.read_excel("C:/Users/ACER/Downloads/DP-02/Project/Actuator_I.xlsx")
data1 = data1.iloc[: , 0:9]
print(data1.shape)
data1
# Out:
# (30, 9)
#     SL_No  Bearing_to_bearing_Length  Driver_Shaft_length  Worm_length  \
# 0       1                 147.719654           127.939450    68.015373
# 1       2                 147.786309           127.937728    68.015137
# 2       3                 148.117257           127.949102    68.006165
# 3       4                 147.718863           127.930838    68.015731
# 4       5                 147.795075           127.938214    68.016452
# 5       6                 147.713383           127.936525    68.013451
# 6       7                 148.124131           127.943756    68.009925
# 7       8                 148.111716           127.942952    68.005997
# 8       9                 148.160882           127.949797    68.004714
# 9      10                 148.190386           127.949415    68.002757
# 10     11                 147.759434           127.932759    68.011119
# 11     12                 148.141185           127.943387    68.007607
# ...

# %%
# Import the IInd dataset Actuator-II
data2 = pd.read_excel("C:/Users/ACER/Downloads/DP-02/Project/Actuator_II.xlsx")
data2.head()
# Out:
#    SL_No  Bearing_to_bearing_Length  Driver_Shaft_length  Worm_length  \
# 0     31                 147.754492           127.934493    68.019427
# 1     32                 147.796452           127.936002    68.014478
# 2     33                 148.125088           127.945418    68.003925
# 3     34                 148.131826           127.945182    68.004625
# 4     35                 147.741767           127.934968    68.015486
#
#   Star_Washer_position  Thickness  Height  Load Torque_Variation
# 0             Worm End      1.501    2.15  3139             High
# 1          Bearing End      1.481    2.14  3119             High
# 2          Bearing End      1.512    2.26  3335              Low
# 3          Bearing End      1.516    2.26  3325              Low
# 4          Bearing End      1.495    2.08  3168             High

# %%
data1['Torque_Variation'].value_counts()
# Out:
# High    17
# Low     13
# Name: Torque_Variation, dtype: int64

# %%
# Append Both the Datasets
new_data = data1.append(data2)
new_data = data1.iloc[: , 0:9]
new_data.head()
# Out:
#    SL_No  Bearing_to_bearing_Length  Driver_Shaft_length  Worm_length  \
# 0      1                 147.719654           127.939450    68.015373
# 1      2                 147.786309           127.937728    68.015137
# 2      3                 148.117257           127.949102    68.006165
# 3      4                 147.718863           127.930838    68.015731
# 4      5                 147.795075           127.938214    68.016452
#
#   Star_Washer_position  Thickness  Height  Load Torque_Variation
# 0          Bearing End      1.468    2.17  2943             High
# 1          Bearing End      1.502    2.19  3090             High
# 2             Worm End      1.518    2.20  3276              Low
# 3          Bearing End      1.480    2.13  2992             High
# 4             Worm End      1.485    2.14  3041             High

# %%
# Export the Dataset
new_data.to_excel("C:/Users/ACER/Downloads/DP-02/Project/Actuator_New_Data.xlsx")

# %%
# Descriptive Summay of Ist Dataset
data1.describe()
# Out:
#            SL_No  Bearing_to_bearing_Length  Driver_Shaft_length  Worm_length  \
# count  30.000000                  30.000000            30.000000    30.000000
# mean   15.500000                 147.919109           127.940382    68.011001
# std     8.803408                   0.205903             0.005498     0.004889
# min     1.000000                 147.700324           127.930838    68.002757
# 25%     8.250000                 147.736448           127.936498    68.007686
# 50%    15.500000                 147.792184           127.939361    68.011637
# 75%    22.750000                 148.136922           127.944036    68.014716
# max    30.000000                 148.196285           127.949797    68.019757
#
#        Thickness     Height         Load
# count  30.000000  30.000000    30.000000
# mean    1.496733   2.186000  3145.100000
# std     0.017567   0.041406   144.430236
# min     1.459000   2.080000  2825.000000
# 25%     1.485000   2.162500  3041.000000
# ...

# %%
# Information of Dataset Ist
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   SL_No                      30 non-null     int64
#  1   Bearing_to_bearing_Length  30 non-null     float64
#  2   Driver_Shaft_length        30 non-null     float64
#  3   Worm_length                30 non-null     float64
#  4   Star_Washer_position       30 non-null     object
#  5   Thickness                  30 non-null     float64
#  6   Height                     30 non-null     float64
#  7   Load                       30 non-null     int64
#  8   Torque_Variation           30 non-null     object
# dtypes: float64(5), int64(2), object(2)
# memory usage: 2.2+ KB

# %%
# Frequency Table
data1_table = data1.value_counts() 
data1_table
# Out:
# SL_No  Bearing_to_bearing_Length  Driver_Shaft_length  Worm_length  Star_Washer_position  Thickness  Height  Load  Torque_Variation
# 1      147.719654                 127.939450           68.015373    Bearing End           1.468      2.17    2943  High                1
# 2      147.786309                 127.937728           68.015137    Bearing End           1.502      2.19    3090  High                1
# 29     147.700324                 127.939944           68.015815    Bearing End           1.487      2.19    2992  High                1
# 28     148.123963                 127.944130           68.003190    Worm End              1.513      2.20    3198  Low                 1
# 27     148.179718                 127.946427           68.004977    Worm End              1.518      2.21    3315  Low                 1
# 26     147.765319                 127.939272           68.011919    Bearing End           1.482      2.19    3060  High                1
# ...

# %%
# Copy the field to new variables
bbl = data1.Bearing_to_bearing_Length
dsl = data1.Driver_Shaft_length
wl= data1.Worm_length
swp = data1.Star_Washer_position
t = data1.Thickness
h = data1.Height
l = data1.Load
tv = data1.Torque_Variation

# %%
bbl.groupby(swp).describe()
# Out:
#                       count        mean       std         min         25%  \
# Star_Washer_position
# Bearing End            16.0  147.919226  0.214388  147.700324  147.732185
# Worm End               14.0  147.918976  0.203819  147.703063  147.741348
#
#                              50%         75%         max
# Star_Washer_position
# Bearing End           147.775814  148.143230  148.196285
# Worm End              147.794512  148.124089  148.179718

# %%
bbl.groupby(tv).describe()
# Out:
#                   count        mean      std         min         25%  \
# Torque_Variation
# High               17.0  147.744119  0.03288  147.700324  147.718863
# Low                13.0  148.147943  0.03010  148.107421  148.123963
#
#                          50%         75%         max
# Torque_Variation
# High              147.736704  147.765319  147.795075
# Low               148.149363  148.169323  148.196285

# %%
bbl.groupby(swp).mean()
# Out:
# Star_Washer_position
# Bearing End    147.919226
# Worm End       147.918976
# Name: Bearing_to_bearing_Length, dtype: float64

# %%
# Boxplot
# import matplotlib library
import matplotlib.pyplot as plt 
data1.boxplot(column="Bearing_to_bearing_Length" , by= "Star_Washer_position")
plt.show()

# %%
# Boxplot
# import matplotlib library
import matplotlib.pyplot as plt 
data1.boxplot(column="Bearing_to_bearing_Length" , by= "Star_Washer_position")
plt.show()

# %%
data1.boxplot(column="Driver_Shaft_length" , by= "Star_Washer_position")
plt.show()

# %%
data1.boxplot(column="Driver_Shaft_length" , by= "Torque_Variation")
plt.show()

# %%
# Bar Chart
import matplotlib.pyplot as plt
plt.hist(bbl)
plt.show()

# %%
# Bar Chart
import matplotlib.pyplot as plt
plt.bar(tv, bbl )
plt.show()

# %%
plt.plot(tv, bbl)
plt.title("Scatterplot b/w Tv  Bbl")
plt.xlabel("Tv")
plt.ylabel("Bbl")
plt.show()

# %%
data1.head()
# Out:
#    SL_No  Bearing_to_bearing_Length  Driver_Shaft_length  Worm_length  \
# 0      1                 147.719654           127.939450    68.015373
# 1      2                 147.786309           127.937728    68.015137
# 2      3                 148.117257           127.949102    68.006165
# 3      4                 147.718863           127.930838    68.015731
# 4      5                 147.795075           127.938214    68.016452
#
#   Star_Washer_position  Thickness  Height  Load Torque_Variation
# 0          Bearing End      1.468    2.17  2943             High
# 1          Bearing End      1.502    2.19  3090             High
# 2             Worm End      1.518    2.20  3276              Low
# 3          Bearing End      1.480    2.13  2992             High
# 4             Worm End      1.485    2.14  3041             High

# %%
plt.plot(tv,dsl)
plt.title("Scatterplot b/w Tv  Bbl")
plt.xlabel("Tv")
plt.ylabel("dsl")
plt.show()

# %%
plt.plot(tv , wl)
plt.title("Scatterplot b/w Tv  Bbl")
plt.xlabel("Tv")
plt.ylabel("Bbl")
plt.show()

# %%
plt.plot(tv, l)
plt.title("Scatterplot b/w Tv  Bbl")
plt.xlabel("Tv")
plt.ylabel("Bbl")
plt.show()

# %%
plt.plot(tv, h)
plt.title("Scatterplot b/w Tv  Bbl")
plt.xlabel("Tv")
plt.ylabel("Bbl")
plt.show()

# %% [markdown]
# Q 2. An application support process like to develop a model to estimate the time taken to resolve the tickets they receive. Through discussions, the project team has identified four explanatory variables suspected to be impacting the resolution time .
# <br>a.  The data is collected on the resolution time and explanatory variables. The explanatory variable data is collected from the company server and is given in Resolution_TimeI file and the resolution time data is collected from client server and is given in Resolution_TimeII file. Kindly merge the two files
# <br>b.  Is the dataset contains missing values ? Replace the missing values with appropriate statistics
# <br>c. Prepare the descriptive summary of each variable after replenishment of missing values
# <br>d. Identify the relationship of explanatory variables with resolution time using appropriate data visualization technique?. Using the graph, kindly identify the variables related to the resolution time?
# <br>e. Scale the variables using z and Min-Max transformations. After each transformation, identify the relationship of explanatory variables with resolution time using appropriate data visualization technique? Is there any change in the relationship of variables with resolution time after transformation ?

# %%
# Import the library
import pandas as pd

# Import the Ist dataset Resolution Time - I
data1 = pd.read_excel("C:/Users/ACER/Downloads/DP-02/Project/Resolution_TimeI.xlsx")
data1.head()
# Out:
#    SL_No  Volume  Team_Experience  Domain_Expertise
# 0      1    69.0             20.0              15.0
# 1      2    84.0             25.0              20.0
# 2      3    72.0             21.0              15.0
# 3      4    79.0             23.0              18.0
# 4      5    20.0             13.0               9.0

# %%
# Import the Ist dataset Resolution Time - II
data2 = pd.read_excel("C:/Users/ACER/Downloads/DP-02/Project/Resolution_TimeII.xlsx")
data2.head()
# Out:
#    SL_No  Resolution_Time
# 0      1              771
# 1      2              863
# 2      3              863
# 3      4              887
# 4      5              185

# %%
merged_data = pd.merge(data1 , data2 , on = "SL_No")
merged_data.head()
# Out:
#    SL_No  Volume  Team_Experience  Domain_Expertise  Resolution_Time
# 0      1    69.0             20.0              15.0              771
# 1      2    84.0             25.0              20.0              863
# 2      3    72.0             21.0              15.0              863
# 3      4    79.0             23.0              18.0              887
# 4      5    20.0             13.0               9.0              185

# %%
# 2.a 
# :- Export the Dataset
merged_data.to_excel("C:/Users/ACER/Downloads/DP-02/Project/Merged_Resolution_Time.xlsx")

# %%
# 2.b :- 
# Deleting records with missing values
del_data = merged_data.dropna() ; del_data.head()
# Out:
#    SL_No  Volume  Team_Experience  Domain_Expertise  Resolution_Time
# 0      1    69.0             20.0              15.0              771
# 1      2    84.0             25.0              20.0              863
# 2      3    72.0             21.0              15.0              863
# 3      4    79.0             23.0              18.0              887
# 4      5    20.0             13.0               9.0              185

# %%
# Mean of Team Experience Column
mte = merged_data.Team_Experience
mte_mean = round(mte.mean() , 3) ;mte_mean
# Out:
# 18.839

# %%
# Replace Missing Values with mean
rep_data= mte.fillna(mte_mean , inplace = True) ; rep_data

# %%
# 2.c 
del_data.describe()
# Out:
#            SL_No     Volume  Team_Experience  Domain_Expertise  \
# count  54.000000  54.000000        54.000000         54.000000
# mean   29.962963  61.055556        18.685185         13.351852
# std    16.492380  19.865032         4.596242          4.171590
# min     1.000000   5.000000         9.000000          5.000000
# 25%    16.500000  59.000000        16.000000         10.000000
# 50%    30.500000  63.500000        19.000000         13.000000
# 75%    43.750000  72.000000        21.000000         16.000000
# max    57.000000  89.000000        31.000000         22.000000
#
#        Resolution_Time
# count        54.000000
# mean        652.000000
# std         229.485561
# min          57.000000
# 25%         558.500000
# 50%         684.500000
# 75%         777.750000
# max        1081.000000

# %%
v = del_data.Volume
te = del_data.Team_Experience
de = del_data.Domain_Expertise
rt = del_data.Resolution_Time

# %%
# 2.d
# import the library
import matplotlib.pyplot as plt
plt.plot(rt , v)
plt.title("Scatterplot b/w Rt & v")
plt.xlabel("Resolution Time")
plt.ylabel("Volume")
plt.show()

# %%
# import the library
import matplotlib.pyplot as plt
plt.plot(rt , te)
plt.title("Scatterplot b/w Rt & Te")
plt.xlabel("Resolution Time")
plt.ylabel("Team Experience")
plt.show()

# %%
# import the library
import matplotlib.pyplot as plt
plt.plot(rt , de)
plt.title("Scatterplot b/w Rt & De")
plt.xlabel("Resolution Time")
plt.ylabel("Domain_Expertise")
plt.show()

# %%
# 2.e
# Read the files
import pandas as pd
from sklearn.preprocessing import StandardScaler as z
from sklearn.preprocessing import MinMaxScaler as minmax
mydata = del_data

# %%
# z transform
std_data = z().fit_transform(mydata) 
std_data = pd.DataFrame(std_data, columns= mydata.columns.values)
std_data.head()
# Out:
#       SL_No    Volume  Team_Experience  Domain_Expertise  Resolution_Time
# 0 -1.764345  0.393782         0.290788          0.389266         0.503431
# 1 -1.702928  1.159985         1.398957          1.605723         0.907645
# 2 -1.641511  0.547023         0.512421          0.389266         0.907645
# 3 -1.580094  0.904584         0.955689          1.119140         1.013092
# 4 -1.518676 -2.109149        -1.260649         -1.070482        -2.071239

# %%
std_data.describe()
# Out:
#               SL_No        Volume  Team_Experience  Domain_Expertise  \
# count  5.500000e+01  5.500000e+01     5.500000e+01      5.500000e+01
# mean  -9.285502e-17  1.635056e-16    -3.027881e-17      2.018587e-18
# std    1.009217e+00  1.009217e+00     1.009217e+00      1.009217e+00
# min   -1.764345e+00 -2.875352e+00    -2.147185e+00     -2.043648e+00
# 25%   -8.123802e-01 -1.170201e-01    -5.957477e-01     -8.271907e-01
# 50%    1.675011e-02  1.383810e-01     6.915379e-02     -9.731656e-02
# 75%    8.458805e-01  5.470228e-01     5.124215e-01      6.325576e-01
# max    1.675011e+00  1.415387e+00     2.728760e+00      2.092306e+00
#
#        Resolution_Time
# count     5.500000e+01
# mean      1.130409e-16
# std       1.009217e+00
# min      -2.633624e+00
# 25%      -4.192326e-01
# 50%       1.255781e-01
# 75%       5.935001e-01
# max       1.865457e+00

# %%
# Min Max transform
tr_data = minmax().fit_transform(mydata) 
tr_data = pd.DataFrame(tr_data, columns= mydata.columns.values) 
tr_data.head()
# Out:
#       SL_No    Volume  Team_Experience  Domain_Expertise  Resolution_Time
# 0  0.000000  0.761905         0.500000          0.588235         0.697266
# 1  0.017857  0.940476         0.727273          0.882353         0.787109
# 2  0.035714  0.797619         0.545455          0.588235         0.787109
# 3  0.053571  0.880952         0.636364          0.764706         0.810547
# 4  0.071429  0.178571         0.181818          0.235294         0.125000

# %%
tr_data.describe()
# Out:
#            SL_No     Volume  Team_Experience  Domain_Expertise  \
# count  55.000000  55.000000        55.000000         55.000000
# mean    0.512987   0.670130         0.440363          0.494118
# std     0.293432   0.235208         0.206979          0.244011
# min     0.000000   0.000000         0.000000          0.000000
# 25%     0.276786   0.642857         0.318182          0.294118
# 50%     0.517857   0.702381         0.454545          0.470588
# 75%     0.758929   0.797619         0.545455          0.647059
# max     1.000000   1.000000         1.000000          1.000000
#
#        Resolution_Time
# count        55.000000
# mean          0.585369
# std           0.224316
# min           0.000000
# 25%           0.492188
# 50%           0.613281
# 75%           0.717285
# max           1.000000

# %%
import seaborn as sns
sns.pairplot(tr_data)
plt.show()
